# %% [markdown]
# <a href="https://colab.research.google.com/github/mccoy0928/20220702-Python/blob/main/DataFrame%E7%B0%A1%E5%96%AE%E6%93%8D%E4%BD%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## 產生隨機資料

# %%
data = np.random.randint(30, 101, (10, 4))

# %% [markdown]
# ## 轉換成 float

# %%
data = data.astype(float)

# %%
for i in range(5):
  x = np.random.randint(0, 10)
  y = np.random.randint(0, 4)
  data[x, y] = np.NaN

# %%
data
# Out:
# array([[72., 93., 99., 36.],
#        [37., 43., nan, 49.],
#        [86., 77., 89., 66.],
#        [75., 49., 59., 49.],
#        [56., nan, 63., 41.],
#        [nan, nan, 74., 42.],
#        [67., 67., 91., 65.],
#        [95., 38., 33., 42.],
#        [nan, 82., 39., 38.],
#        [86., 30., 77., 45.]])

# %% [markdown]
# ## 轉換成 DataFrame

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#       0     1     2     3
# 0  72.0  93.0  99.0  36.0
# 1  37.0  43.0   NaN  49.0
# 2  86.0  77.0  89.0  66.0
# 3  75.0  49.0  59.0  49.0
# 4  56.0   NaN  63.0  41.0
# 5   NaN   NaN  74.0  42.0
# 6  67.0  67.0  91.0  65.0
# 7  95.0  38.0  33.0  42.0
# 8   NaN  82.0  39.0  38.0
# 9  86.0  30.0  77.0  45.0

# %%
df.columns = ['國文','英文','數學','理化']

# %%
df
# Out:
#      國文    英文    數學    理化
# 0  72.0  93.0  99.0  36.0
# 1  37.0  43.0   NaN  49.0
# 2  86.0  77.0  89.0  66.0
# 3  75.0  49.0  59.0  49.0
# 4  56.0   NaN  63.0  41.0
# 5   NaN   NaN  74.0  42.0
# 6  67.0  67.0  91.0  65.0
# 7  95.0  38.0  33.0  42.0
# 8   NaN  82.0  39.0  38.0
# 9  86.0  30.0  77.0  45.0

# %%
df.index = ["林怡婷","趙必桂","錢詩婷","鄭泰州","陳祐侑","林惠貴","藍以舜","韓清勇","黃子喬","張揚芃"]

# %%
df
# Out:
#        國文    英文    數學    理化
# 林怡婷  72.0  93.0  99.0  36.0
# 趙必桂  37.0  43.0   NaN  49.0
# 錢詩婷  86.0  77.0  89.0  66.0
# 鄭泰州  75.0  49.0  59.0  49.0
# 陳祐侑  56.0   NaN  63.0  41.0
# 林惠貴   NaN   NaN  74.0  42.0
# 藍以舜  67.0  67.0  91.0  65.0
# 韓清勇  95.0  38.0  33.0  42.0
# 黃子喬   NaN  82.0  39.0  38.0
# 張揚芃  86.0  30.0  77.0  45.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, 林怡婷 to 張揚芃
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   國文      8 non-null      float64
#  1   英文      8 non-null      float64
#  2   數學      9 non-null      float64
#  3   理化      10 non-null     float64
# dtypes: float64(4)
# memory usage: 400.0+ bytes

# %% [markdown]
# ## 刪除缺失值

# %% [markdown]
# * dropna()

# %%
df.dropna()
# Out:
#        國文    英文    數學    理化
# 林怡婷  72.0  93.0  99.0  36.0
# 錢詩婷  86.0  77.0  89.0  66.0
# 鄭泰州  75.0  49.0  59.0  49.0
# 藍以舜  67.0  67.0  91.0  65.0
# 韓清勇  95.0  38.0  33.0  42.0
# 張揚芃  86.0  30.0  77.0  45.0

# %%
df.dropna(subset=['國文'])
# Out:
#        國文    英文    數學    理化
# 林怡婷  72.0  93.0  99.0  36.0
# 趙必桂  37.0  43.0   NaN  49.0
# 錢詩婷  86.0  77.0  89.0  66.0
# 鄭泰州  75.0  49.0  59.0  49.0
# 陳祐侑  56.0   NaN  63.0  41.0
# 藍以舜  67.0  67.0  91.0  65.0
# 韓清勇  95.0  38.0  33.0  42.0
# 張揚芃  86.0  30.0  77.0  45.0

# %%
df['國文'].notnull()
# Out:
# 林怡婷     True
# 趙必桂     True
# 錢詩婷     True
# 鄭泰州     True
# 陳祐侑     True
# 林惠貴    False
# 藍以舜     True
# 韓清勇     True
# 黃子喬    False
# 張揚芃     True
# Name: 國文, dtype: bool

# %%
df[df['國文'].notnull()]
# Out:
#        國文    英文    數學    理化
# 林怡婷  72.0  93.0  99.0  36.0
# 趙必桂  37.0  43.0   NaN  49.0
# 錢詩婷  86.0  77.0  89.0  66.0
# 鄭泰州  75.0  49.0  59.0  49.0
# 陳祐侑  56.0   NaN  63.0  41.0
# 藍以舜  67.0  67.0  91.0  65.0
# 韓清勇  95.0  38.0  33.0  42.0
# 張揚芃  86.0  30.0  77.0  45.0

# %%
df.dropna(axis=1)
# Out:
#        理化
# 林怡婷  36.0
# 趙必桂  49.0
# 錢詩婷  66.0
# 鄭泰州  49.0
# 陳祐侑  41.0
# 林惠貴  42.0
# 藍以舜  65.0
# 韓清勇  42.0
# 黃子喬  38.0
# 張揚芃  45.0

# %% [markdown]
# ## 填補缺失值

# %% [markdown]
# * fillna()

# %%
df['國文'].fillna(value=df['國文'].mean())
# Out:
# 林怡婷    72.00
# 趙必桂    37.00
# 錢詩婷    86.00
# 鄭泰州    75.00
# 陳祐侑    56.00
# 林惠貴    71.75
# 藍以舜    67.00
# 韓清勇    95.00
# 黃子喬    71.75
# 張揚芃    86.00
# Name: 國文, dtype: float64

# %%
df
# Out:
#        國文    英文    數學    理化
# 林怡婷  72.0  93.0  99.0  36.0
# 趙必桂  37.0  43.0   NaN  49.0
# 錢詩婷  86.0  77.0  89.0  66.0
# 鄭泰州  75.0  49.0  59.0  49.0
# 陳祐侑  56.0   NaN  63.0  41.0
# 林惠貴   NaN   NaN  74.0  42.0
# 藍以舜  67.0  67.0  91.0  65.0
# 韓清勇  95.0  38.0  33.0  42.0
# 黃子喬   NaN  82.0  39.0  38.0
# 張揚芃  86.0  30.0  77.0  45.0

# %%
df.fillna(method='backfill')
# Out:
#        國文    英文    數學    理化
# 林怡婷  72.0  93.0  99.0  36.0
# 趙必桂  37.0  43.0  89.0  49.0
# 錢詩婷  86.0  77.0  89.0  66.0
# 鄭泰州  75.0  49.0  59.0  49.0
# 陳祐侑  56.0  67.0  63.0  41.0
# 林惠貴  67.0  67.0  74.0  42.0
# 藍以舜  67.0  67.0  91.0  65.0
# 韓清勇  95.0  38.0  33.0  42.0
# 黃子喬  86.0  82.0  39.0  38.0
# 張揚芃  86.0  30.0  77.0  45.0

# %% [markdown]
# ## 簡單資料分析

# %%
df = df.fillna(method='backfill')

# %%
df
# Out:
#        國文    英文    數學    理化
# 林怡婷  72.0  93.0  99.0  36.0
# 趙必桂  37.0  43.0  89.0  49.0
# 錢詩婷  86.0  77.0  89.0  66.0
# 鄭泰州  75.0  49.0  59.0  49.0
# 陳祐侑  56.0  67.0  63.0  41.0
# 林惠貴  67.0  67.0  74.0  42.0
# 藍以舜  67.0  67.0  91.0  65.0
# 韓清勇  95.0  38.0  33.0  42.0
# 黃子喬  86.0  82.0  39.0  38.0
# 張揚芃  86.0  30.0  77.0  45.0

# %%
df['國文'] < 60
# Out:
# 林怡婷    False
# 趙必桂     True
# 錢詩婷    False
# 鄭泰州    False
# 陳祐侑     True
# 林惠貴    False
# 藍以舜    False
# 韓清勇    False
# 黃子喬    False
# 張揚芃    False
# Name: 國文, dtype: bool

# %%
df[df['國文'] < 60]
# Out:
#        國文    英文    數學    理化
# 趙必桂  37.0  43.0  89.0  49.0
# 陳祐侑  56.0  67.0  63.0  41.0

# %%
df[(df['國文'] < 60) & (df['英文'] < 60)]
# Out:
#        國文    英文    數學    理化
# 趙必桂  37.0  43.0  89.0  49.0

# %% [markdown]
# ## GroupBy

# %%
df = pd.DataFrame({'Animal': ['Falcon', 'Falcon',
                              'Parrot', 'Parrot'],
                   'Max Speed': [380., 370., 24., 26.]})

# %%
df
# Out:
#    Animal  Max Speed
# 0  Falcon      380.0
# 1  Falcon      370.0
# 2  Parrot       24.0
# 3  Parrot       26.0

# %%
df.groupby(['Animal']).mean()
# Out:
#         Max Speed
# Animal
# Falcon      375.0
# Parrot       25.0

# %%
df.groupby(['Animal']).count()
# Out:
#         Max Speed
# Animal
# Falcon          2
# Parrot          2

# %%
df.groupby(['Animal']).sum()
# Out:
#         Max Speed
# Animal
# Falcon      750.0
# Parrot       50.0

# %%
groups = df.groupby(['Animal'])

# %%
groups.get_group('Falcon')
# Out:
#    Animal  Max Speed
# 0  Falcon      380.0
# 1  Falcon      370.0

# %%
groups.mean()
# Out:
#         Max Speed
# Animal
# Falcon      375.0
# Parrot       25.0

# %%
pd.cut(np.array([1, 7, 5, 4, 6, 3]), 3)
# Out:
# [(0.994, 3.0], (5.0, 7.0], (3.0, 5.0], (3.0, 5.0], (5.0, 7.0], (0.994, 3.0]]
# Categories (3, interval[float64, right]): [(0.994, 3.0] < (3.0, 5.0] < (5.0, 7.0]]

# %%
pd.cut(np.array([1, 7, 5, 4, 6, 3]), 3, labels=[1, 2, 3])
# Out:
# [1, 3, 2, 2, 3, 1]
# Categories (3, int64): [1 < 2 < 3]

# %% [markdown]
# ## DataFrame 的 indexing 跟 slicing

# %%
data = np.random.randint(30, 101, (10, 4))

# %%
df = pd.DataFrame(data)

# %%
df.columns = ['國文','英文','數學','理化']

# %%
df.index = ["林怡婷","趙必桂","錢詩婷","鄭泰州","陳祐侑","林惠貴","藍以舜","韓清勇","黃子喬","張揚芃"]

# %%
df
# Out:
#      國文   英文  數學  理化
# 林怡婷  33   34  90  48
# 趙必桂  81   65  96  56
# 錢詩婷  70   51  45  76
# 鄭泰州  41   94  50  65
# 陳祐侑  46   49  39  36
# 林惠貴  47   68  55  78
# 藍以舜  85  100  73  80
# 韓清勇  42   50  81  57
# 黃子喬  46   85  66  52
# 張揚芃  95   84  94  58

# %%
df.loc['鄭泰州']
# Out:
# 國文    41
# 英文    94
# 數學    50
# 理化    65
# Name: 鄭泰州, dtype: int64

# %%
df['鄭泰州']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '鄭泰州'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df[['國文','英文']]
# Out:
#      國文   英文
# 林怡婷  33   34
# 趙必桂  81   65
# 錢詩婷  70   51
# 鄭泰州  41   94
# 陳祐侑  46   49
# 林惠貴  47   68
# 藍以舜  85  100
# 韓清勇  42   50
# 黃子喬  46   85
# 張揚芃  95   84

# %%
df.iloc[3]
# Out:
# 國文    41
# 英文    94
# 數學    50
# 理化    65
# Name: 鄭泰州, dtype: int64

# %%
df.iloc[3:5]
# Out:
#      國文  英文  數學  理化
# 鄭泰州  41  94  50  65
# 陳祐侑  46  49  39  36

# %%
df.loc['鄭泰州':'林惠貴']
# Out:
#      國文  英文  數學  理化
# 鄭泰州  41  94  50  65
# 陳祐侑  46  49  39  36
# 林惠貴  47  68  55  78

# %% [markdown]
# ## Pivot Table

# %%
import matplotlib.pyplot as plt
import seaborn as sns

flights = sns.load_dataset("flights")

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
flights = flights.pivot("month", "year", "passengers")

# %%
flights
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
ax = sns.heatmap(flights)

# %%
ax = sns.heatmap(flights, annot=True, fmt="d")

# %% [markdown]
# ## Lambda Function

# %%
def square(x):
  return x**2

# %%
square(2)
# Out:
# 4

# %%
square2 = lambda x: x**2

# %%
square2(2)
# Out:
# 4

# %%
x = 1
y = 1 if x > 0 else 0
y
# Out:
# 1
